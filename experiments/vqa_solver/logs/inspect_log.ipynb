# %%
import pandas as pd
from ast import literal_eval

# %%
logs = pd.read_csv('log.csv')

# %%
logs
# Out:
#                                   exp_id        custom_tag  \
# 0   3ece2209-641f-4f3c-b686-9f87ba50be68         debug_vqa
# 1   c0b4ac23-5278-43bb-8d6d-44e94457cb83         debug_vqa
# 2   1bd23496-a346-487c-a8a6-bbbbea5a59f9         debug_vqa
# 3   bc069ea5-3928-4f84-b8e7-931cdbe1273e         debug_vqa
# 4   c42ab211-e547-47a8-8f78-3099e8e1b449         debug_vqa
# ..                                   ...               ...
# 66                  cdr15fdame5q2lki4jtg  ehningen_16nov22
# 67                  cdr15n5nfm78gd4naitg  ehningen_16nov22
# 68                  cdr161621u45244a15j0  ehningen_16nov22
# 69                  cdr167qs6h6ldospj2o0  ehningen_16nov22
# 70                  cdrov2eqm5bv7jt5d830  ehningen_15nov22
#
#                 job_time               programm_id        backend  exact  \
# 0   10/11/2022, 14:09:30  vqa-poisson1d-zZlPMA0KqZ      simulator  False
# 1   10/11/2022, 14:09:56  vqa-poisson1d-zZlPMA0KqZ      simulator  False
# ...

# %%
target    = 'ibmq_ehningen'
tag       = 'full_vqa_aer_spsa_custom_hyper_1'
optimizer = 'L_BFGS_B'
row       = logs.tail(60)
row[['exp_id', 'custom_tag', 'optimizer', 'shots', 'cost', 'mapomatic']]
# Out:
#                   exp_id        custom_tag optimizer  shots            cost  \
# 11  cdn3os88d2t5hfpm52jg         test_qasm      SPSA    100  Sato21_Nonnorm
# 12  cdn3t41o5iu6hiqc7tjg         test_qasm       NFT    100  Sato21_Nonnorm
# 13  cdn3udg8d2t5hfpm6n4g         test_qasm       NFT    100  Sato21_Nonnorm
# 14  cdn3vpfjab64ufio8n5g         test_qasm    POWELL    100  Sato21_Nonnorm
# 15  cdn40pfjab64ufio90d0         test_qasm  L_BFGS_B    100  Sato21_Nonnorm
# 16  cdn5315li5umfujbh43g  ehningen_11nov22       NFT  10000  Sato21_Nonnorm
# 17  cdn556ho5iu6hiqcj2b0     lagos_11nov22       NFT  10000  Sato21_Nonnorm
# 18  cdnq4n7trt2d1cmfoh7g  ehningen_11nov22       NFT  10000  Sato21_Nonnorm
# 19  cdnq5rl1lma74nd124eg  ehningen_11nov22       NFT  10000  Sato21_Nonnorm
# 20  cdnu08ntrt2d1cmfoj0g  ehningen_11nov22       NFT  10000  Sato21_Nonnorm
# 21  cdojedlli5umfujbinf0  ehningen_13nov22       NFT   1000  Sato21_Nonnorm
# ...

# %%
logs['custom_tag'].values[2300:2400]
# Out:
# array(['full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_spsa_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_spsa_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_spsa_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_spsa_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_bfgs_1', 'full_vqa_aer_bfgs_1',
#        'full_vqa_aer_spsa_1', 'full_vqa_aer_spsa_1',
# ...

# %%
row
# Out:
#                                     exp_id                        custom_tag  \
# 2806                  cdihtadf8p0nsa6v6jg0                  vqa_run_4nov2022
# 2807                  cdihti4gup47ljrjrrm0                  vqa_run_4nov2022
# 2808                  cdihtq5f8p0nsa6v6ln0                  vqa_run_4nov2022
# 2809                  cdihu1tmeqb933sln4e0                  vqa_run_4nov2022
# 2810                  cdihu9f6dfokn7eknk70                  vqa_run_4nov2022
# 2811                  cdihukv6dfokn7eknlr0                  vqa_run_4nov2022
# 2812                  cdihuvdf8p0nsa6v6rcg                  vqa_run_4nov2022
# 2813                  cdihv7oui13joabqcirg                  vqa_run_4nov2022
# 2814                  cdihvflmeqb933slnb0g                  vqa_run_4nov2022
# 2815                  cdihvndmeqb933slnc3g                  vqa_run_4nov2022
# 2816                  cdihvu8ui13joabqclr0                  vqa_run_4nov2022
# ...
